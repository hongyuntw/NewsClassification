# %%
import pandas as pd
import numpy as np
import re
import ast

# %%
def clean_string(content):
#     cc = OpenCC('t2s')
    content = content.replace('\n','。').replace('\t','，').replace('!', '！').replace('?', '？')# erease white space cause English name error
    content = re.sub("[+\.\/_,$%●▼►^*(+\"\']+|[+——~@#￥%……&*（）★]", "",content)
    content = re.sub(r"[%s]+" %stops, "。",content)
#     content = cc.convert(content)
    return content

def cut_sent(para):
    para = re.sub('([。！？\?])([^”’])', r"\1\n\2", para)
    para = re.sub('(\.{6})([^”’])', r"\1\n\2", para) 
    para = re.sub('(\…{2})([^”’])', r"\1\n\2", para)  
    para = re.sub('([。！？\?][”’])([^，。！？\?])', r'\1\n\2', para)
    return para.split("\n")


def combine_sentence(sentences , max_len):
    li = []
    string = ''
    for k in range(len(sentences)):
        sentence = sentences[k]
        if len(string) + len(sentence) < max_len:
            string = string + sentence
        else:
#             原本是空的代表sentences太長
            if string == '':
                n = max_len
                tmp_li = [sentence[i:i+n] for i in range(0, len(sentence), n)]
                string = tmp_li.pop(-1)
                li = li + tmp_li
            else:
                li.append(string)
                string = sentence
    if(string != ''):
        li.append(string)
    return li

# %%
data = pd.read_csv('./tbrain/tbrain_train.csv')
# data = np.array(data)
# data
max_length = 0
for index,row in data.iterrows():
    content = row['full_content']
    content = clean_string(content)
    if(len(content)>max_length):
        max_length = content
print(max_length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-570fd8d4f251> in <module>
#       5 for index,row in data.iterrows():
#       6     content = row['full_content']
# ----> 7     content = clean_string(content)
#       8     if(len(content)>max_length):
#       9         max_length = content
#
# <ipython-input-18-6fe782f5d6ae> in clean_string(content)
#       3     content = content.replace('\n','。').replace('\t','，').replace('!', '！').replace('?', '？')# erease white space cause English name error
#       4     content = re.sub("[+\.\/_,$%●▼►^*(+\"\']+|[+——~@#￥%……&*（）★]", "",content)
# ----> 5     content = re.sub(r"[%s]+" %stops, "。",content)
#       6 #     content = cc.convert(content)
#       7     return content
#
# NameError: name 'stops' is not defined

# %%
correct =data[data['binary']==1]

correct
# Out:
#                                                article  binary  \
# 27   〔記者黃建華／高雄報導〕前仁武派出所所長何水巡任職交通大隊期間，涉嫌無償協助賭博電玩業者按月...       1
# 36   〔記者李松靖／台北報導〕只有國小學歷的騙徒陳致遠，謊稱「世界國安基金會」山字輩千億美金的管理...       1
# 53   【綜合報導】退伍的消防替代役男陳俊希，前年9月利用曾在台中消防局大雅消防分隊服替代役，熟知消...       1
# 64   〔記者丁偉杰／嘉義報導〕從事人力仲介的嘉義市「星晟國際有限公司」負責人陳致遠，被控夥同員工及...       1
# 84   華南永昌證券前董事長許育心12年前於任內，利用處理益通光能公司股票初次上櫃前公開承銷作業之便...       1
# 87   前監察委員余哲榮、柏美建設前董事長祁姵瑜，被控與海天保全董事長黃千菁偽造不實債權向法院聲請強...       1
# 90   太平洋電線電纜公司前董事長池豪蓮因積欠1.2億元稅金未繳，2016年遭行政執行署新北分署向法...       1
# 101  〔記者陳政甫／桃園報導〕桃園市榮騰網路行銷公司（簡稱榮騰公司）負責人劉冠恬，從2013年10...       1
# 364  〔記者陳政甫／台北報導〕黑道網紅林于岳引爆「高雄之亂」治安紛擾後，台北市警方鎖定與林于岳同掛...       1
# 370  〔記者陳政甫／台北報導〕警員曾裕仁擔任高雄林園分局行政組巡佐時，涉收受賄款160萬元包庇電玩...       1
#
#                                              ckip_name  \
# 27           ['王玉明', '林佐漢', '何員', '李林豐', '黃建華', '何水巡']
# 36            ['陳致遠', '山字輩', '李松靖', '王勇志', '陳男', '陳董']
# 53                 ['黃連', '陳俊希', '陳男', '方韋成', '本尊方韋成']
# 64                 ['陳致遠', '丁偉杰', '鄭柏廷', '許皓彥', '張涵寧']
# 84   ['黃哲民', '林秀瑋', '林男', '林女', '永昌', '許育心', '林怡伶',...
# 87           ['余哲榮', '余未', '祁姵瑜', '祁，祁', '黃千菁', '蔡宛音']
# 90                 ['侯怡靜', '吳雅沛', '池豪蓮', '鄭信宏', '黃明倫']
# 101   ['彭俊緯', '陳政甫', '劉冠恬', '白琳治', '何淑卿', '榮騰', '涂婉如']
# 111                                     ['郭詠奇', '胡竣泉']
# 113           ['范男', '鐘佳燕', '范志宏', '施仁旭', '范嫌', '王克亦']
# 115                                      ['瀚克', '林韋志']
# 129                              ['林郁雯', '羅友菱', '吳宛財']
# 161                                            ['林威成']
# 178                                     ['林雅屏', '許宛玲']
# 180  ['陳怡岑', '張智元', '李石良', '吳裕翔', '黃念心', '游怡如', '林子芸']
# 205                                     ['張舒宸', '簡怡秀']
# 224                       ['陳珮發', '吳舒羽', '李誠芬', '黃小軒']
# 253                       ['謝政哲', '曾裕仁', '徐彩媚', '趙豪伸']
# 265                 ['陳瑋倫', '救富里', '林燕樺', '清清', '徐雲其']
# 267                                            ['張昱廷']
# 274    ['黃靜天', '許男', '張瑋年', '曾靖雅', '黃男', '許宏儒', '王吟芳']
# 291                  ['中清龍', '小冰冰', '吳雨木', '吳男', '鍾男']
# 293                                            ['吳慧敏']
# 298  ['唐雅雯', '林秀琦', '李碧青', '富南斯', '李海喜', '林雅云', '林宗...
# 300            ['黃上訴', '黃未', '黃男', '黃入監', '黃確', '黃信怡']
# 303        ['但林', '蔡雅歡', '林佳慧', '林與林佳慧', '林盈中', '陳玠源']
# 304                ['劉智超', '劉成秀', '劉舜宜', '楊明星', '劉惠雯']
# 310                       ['鐘辛禾', '羅則嬌', '凌晨訊', '王子南']
# 317                               ['張博友', '馮男', '馮智堯']
# 321                                 ['謝郁涵', 'Natasha']
# 323    ['黃靜天', '陳瑋婷', '陳慰慈', '陳俊希', '阿元', '黃男', '陳弘俊']
# 345                                     ['吳宛財', '王韻婷']
# 364                  ['陳政甫', '鄧男', '林于岳', '仁會', '黃于安']
# 370                               ['陳政甫', '裕仁', '曾裕仁']
#
#                                    predict_name
# 27                 ['李林豐', '王玉明', '林佐漢', '何水巡']
# 36                               ['陳致遠', '王勇志']
# 53                               ['方韋成', '陳俊希']
# 64                 ['陳致遠', '張涵寧', '鄭柏廷', '許皓彥']
# 84                                      ['許育心']
# 87                               ['黃千菁', '余哲榮']
# 90                        ['鄭信宏', '黃明倫', '池豪蓮']
# 101                ['劉冠恬', '彭俊緯', '白琳治', '何淑卿']
# 111                              ['郭詠奇', '胡竣泉']
# 113                                     ['范志宏']
# 115                                     ['林韋志']
# 129                              ['羅友菱', '吳宛財']
# 161                                     ['林威成']
# 178                                     ['許宛玲']
# 180                       ['陳怡岑', '張智元', '林子芸']
# 205                                     ['張舒宸']
# 224                ['陳珮發', '吳舒羽', '李誠芬', '黃小軒']
# 253                              ['曾裕仁', '趙豪伸']
# 265                              ['陳瑋倫', '林燕樺']
# 267                                     ['張昱廷']
# 274                              ['黃靜天', '許宏儒']
# 291                                     ['吳雨木']
# 293                                     ['吳慧敏']
# 298  ['唐雅雯', '林秀琦', '李碧青', '鄭旭丹', '林宗威', '陳雅映']
# 300                                     ['黃信怡']
# 303              ['陳玠源', '林盈中', '蔡雅歡', '林與林佳慧']
# 304                       ['劉惠雯', '劉成秀', '劉舜宜']
# 310                              ['羅則嬌', '王子南']
# 317                                     ['馮智堯']
# 321                                     ['謝郁涵']
# 323                ['黃靜天', '陳俊希', '陳弘俊', '陳瑋婷']
# 345                                     ['吳宛財']
# 364                              ['林于岳', '黃于安']
# 370                                     ['曾裕仁']

# %%
correct =data[data['binary']==1]
correct = np.array(correct) 
print(correct[23])
# Out:
# ['Line、臉書、手機簡訊，常可見「代客操作股票績效良好，每年保證獲利10％以上」等訊息，吸引投資人買投資課程或加入會員，等到投資人發現未獲利才知受騙。兆宇國際法律事務所律師林雅云指出，這類「保證獲利」的話術會一再得逞，都是利用人性貪婪的弱點，天底下根本沒有保證獲利的投資工具，投資人只要謹記廣告詞：「投資一定有風險，基金投資有賺有賠，申購前應詳閱公開說明書。」就不會被騙。  代操美國股票 半年還本都是假 打著英國天后林宗威、鄭旭丹、林秀琦等大牌藝人名氣造勢的國際投資公司「富南斯」集團，宣稱由AI人工智慧代操美國股票，打著保證獲利16%，「半年還本、一年翻倍」的口號，就是典型以「保證獲利」的話術，來吸引投資人上鉤。  台北地檢署調查，「富南斯」集團自民國自2017年6月起，在台北、台中等地舉辦說明會招募會員，宣稱每投資單位為1萬美元，由公司代為炒作美股，保證半年回本、一年翻倍，每月獲利16%。  北檢調查，「富南斯」集團以老鼠會方式吸收會員，2年來吸金至少新台幣30億元，上月21日才將藝人李海喜的父親李碧青、唐雅雯等10名幹部，依涉犯銀行法向法院聲押禁見獲准。  不僅「富南斯」，上個月被台北地檢署依違反證券投資信託及顧問法及期貨交易法起訴的陳雅映，也以「保證獲利」的話術，來引誘投資人。  進階課程要價25萬 狂賺近3000萬學費 北檢調查，37歲的「Great老師」陳雅映是台大地質系和化工系雙主修畢業，但她並沒有任何證券或期貨投顧的專業證照，卻成立達利國際顧問公司，開設「Great Trading Studio專業交易教學」課程招攬學生。  此課程僅新手外匯課程1堂就要5萬8,888元，2個月短線長線ETF（指數型證券投資信託基金）進階課程更要價25萬元，狂賺百名學員約2,949萬元學費。多位被害人發覺受騙，向檢調告發。  林雅云提醒投資人，政府明定須取得分析師執照，才能向投資人推薦股票，連證券公司營業員也不能向投資人推薦股票，投資人最好委任有立案的投顧公司，保障自身權益。  林雅云指出，這類打著「保證獲利」的話術之所以會詐騙成功，都是利用人性貪婪的弱點，但天底下沒有一種投資工具可以穩賺不賠。若有，國家五大基金也不會虧本，國家也就不用年金改革。'
#  1 "['唐雅雯', '林秀琦', '李碧青', '富南斯', '李海喜', '林雅云', '林宗威', '鄭旭丹', '陳雅映']"
#  "['唐雅雯', '林秀琦', '李碧青', '鄭旭丹', '林宗威', '陳雅映']"]

# %%
data = pd.read_csv('./tbrain/2020-07-30_ans.csv')
ans_list = []
correct =data[data['binary']==1]
for index,row in correct.iterrows():
    name_ans = ast.literal_eval(row['ans'])
    ans_list.append(name_ans)
ans_list
# Out:
# [['李林豐', '王玉明', '林佐漢', '何水巡'],
#  ['陳致遠', '王勇志'],
#  ['陳俊希'],
#  ['陳致遠', '張涵寧', '鄭柏廷', '許皓彥'],
#  ['許育心', '林秀瑋', '林怡伶'],
#  ['黃千菁', '余哲榮', '祁姵瑜'],
#  ['鄭信宏', '黃明倫', '池豪蓮'],
#  ['劉冠恬', '涂婉如', '彭俊緯', '白琳治', '何淑卿'],
#  ['郭詠奇', '胡竣泉'],
#  ['范志宏'],
#  ['林韋志'],
#  ['羅友菱'],
#  ['林威成'],
#  ['許宛玲'],
#  ['陳怡岑', '張智元', '游怡如', '林子芸'],
#  ['張舒宸'],
#  ['吳舒羽'],
#  ['曾裕仁', '趙豪伸'],
#  ['陳瑋倫'],
#  ['張昱廷'],
#  ['黃靜天', '許宏儒'],
#  ['吳雨木'],
#  ['吳慧敏'],
#  ['唐雅雯', '李碧青', '陳雅映'],
#  ['黃信怡'],
#  ['陳玠源', '林盈中', '蔡雅歡', '林佳慧'],
#  ['劉惠雯', '劉成秀', '劉舜宜'],
#  ['鐘辛禾', '羅則嬌', '王子南'],
#  ['馮智堯'],
#  ['謝郁涵'],
#  ['黃靜天', '陳俊希', '陳弘俊', '陳瑋婷'],
#  ['吳宛財'],
#  ['林于岳', '黃于安'],
#  ['曾裕仁']]

# %%
pred = pd.read_csv('./tbrain/2020-07-30_QA_validation.csv')
pred
# Out:
#     idx                                            article  \
# 0    27  〔記者黃建華／高雄報導〕前仁武派出所所長何水巡任職交通大隊期間，涉嫌無償協助賭博電玩業者按月...
# 1    36  〔記者李松靖／台北報導〕只有國小學歷的騙徒陳致遠，謊稱「世界國安基金會」山字輩千億美金的管理...
# 2    53  【綜合報導】退伍的消防替代役男陳俊希，前年9月利用曾在台中消防局大雅消防分隊服替代役，熟知消...
# 3    64  〔記者丁偉杰／嘉義報導〕從事人力仲介的嘉義市「星晟國際有限公司」負責人陳致遠，被控夥同員工及...
# 4    84  華南永昌證券前董事長許育心12年前於任內，利用處理益通光能公司股票初次上櫃前公開承銷作業之便...
# 5    87  前監察委員余哲榮、柏美建設前董事長祁姵瑜，被控與海天保全董事長黃千菁偽造不實債權向法院聲請強...
# 6    90  太平洋電線電纜公司前董事長池豪蓮因積欠1.2億元稅金未繳，2016年遭行政執行署新北分署向法...
# 30  323  〔記者陳慰慈／新北報導〕陳瑋婷、陳弘俊、陳俊希3姊弟，涉嫌和綽號「阿元」的46歲男子黃靜天共...
# 31  345  〔記者王韻婷／高雄報導〕台聯高雄市議員候選人吳宛財涉嫌賄選傳拘不到，選前一天遭高雄地檢署發布...
# 32  364  〔記者陳政甫／台北報導〕黑道網紅林于岳引爆「高雄之亂」治安紛擾後，台北市警方鎖定與林于岳同掛...
# 33  370  〔記者陳政甫／台北報導〕警員曾裕仁擔任高雄林園分局行政組巡佐時，涉收受賄款160萬元包庇電玩...
#
#                                            BIO_output  \
# 0                    {'', '林佐漢', '何水巡', '王玉明', '李林豐'}
# 1                            {'', '陳董', '王勇志', '陳致遠'}
# 2                                {'方韋成', '陳男', '陳俊希'}
# 3                    {'', '鄭柏廷', '許皓彥', '張涵寧', '陳致遠'}
# 4                           {'永昌', '', '華南永昌', '許育心'}
# 5                         {'祁姵瑜', '黃千菁', '余未', '余哲榮'}
# 6                           {'鄭信宏', '池豪蓮', '黃明倫', ''}
# 7           {'榮騰', '白琳治', '涂婉如', '何淑卿', '劉冠恬', '彭俊緯'}
# 8                                      {'郭詠奇', '胡竣泉'}
# 9                           {'范志宏', '王克亦', '', '施仁旭'}
# 10                                      {'瀚克', '林韋志'}
# 11                                 {'', '吳宛財', '羅友菱'}
# 12                                            {'林威成'}
# 13                                     {'林雅屏', '許宛玲'}
# 14                       {'林子芸', '張智元', '游怡如', '陳怡岑'}
# 15                                        {'', '張舒宸'}
# 16                       {'陳珮發', '李誠芬', '黃小軒', '吳舒羽'}
# 17                       {'曾裕仁', '徐彩媚', '趙豪伸', '謝政哲'}
# 18                        {'徐雲其', '林燕樺', '清清', '陳瑋倫'}
# 19                                        {'', '張昱廷'}
# 20                   {'', '黃靜天', '曾靖雅', '張瑋年', '許宏儒'}
# 21                                        {'吳雨木', ''}
# 22                                            {'吳慧敏'}
# 23  {'富南斯', '鄭旭丹', '陳雅映', '林秀琦', '林雅云', '唐雅雯', '李碧...
# 24                                     {'黃上訴', '黃信怡'}
# 25        {'蔡雅歡', '林與林佳慧', '林盈中', '林佳慧', '陳玠源', '但林'}
# 26                       {'劉舜宜', '劉惠雯', '劉成秀', '劉智超'}
# 27                              {'羅則嬌', '王子南', '鐘辛禾'}
# 28                                     {'馮智堯', '張博友'}
# 29                                        {'謝郁涵', ''}
# 30       {'', '黃靜天', '陳弘俊', '黃男', '陳瑋婷', '陳俊希', '阿元'}
# 31                                            {'吳宛財'}
# 32                                 {'', '林于岳', '黃于安'}
# 33                                      {'曾裕仁', '裕仁'}
#
#                                       QAoutput  \
# 0                 ['何水巡', '李林豐', '林佐漢', '王玉明']
# 1                               ['王勇志', '陳致遠']
# 2                                      ['方韋成']
# 3                 ['張涵寧', '許皓彥', '鄭柏廷', '陳致遠']
# 4                                      ['許育心']
# 5                        ['余哲榮', '祁姵瑜', '黃千菁']
# 6                        ['池豪蓮', '鄭信宏', '黃明倫']
# 7          ['何淑卿', '劉冠恬', '彭俊緯', '涂婉如', '白琳治']
# 8                               ['胡竣泉', '郭詠奇']
# 9                                      ['范志宏']
# 10                                     ['林韋志']
# 11                              ['吳宛財', '羅友菱']
# 12                                     ['林威成']
# 13                              ['林雅屏', '許宛玲']
# 14                ['張智元', '林子芸', '游怡如', '陳怡岑']
# 15                                     ['張舒宸']
# 16                              ['吳舒羽', '李誠芬']
# 17                       ['徐彩媚', '曾裕仁', '趙豪伸']
# 18                       ['徐雲其', '林燕樺', '陳瑋倫']
# 19                                     ['張昱廷']
# 20                              ['曾靖雅', '黃靜天']
# 21                                     ['吳雨木']
# 22                                     ['吳慧敏']
# 23  ['唐雅雯', '李海喜', '李碧青', '林宗威', '林秀琦', '鄭旭丹']
# 24                                     ['黃信怡']
# 25                              ['蔡雅歡', '陳玠源']
# 26                       ['劉惠雯', '劉成秀', '劉舜宜']
# 27                              ['王子南', '鐘辛禾']
# 28                                     ['馮智堯']
# 29                                     ['謝郁涵']
# 30                                     ['黃靜天']
# 31                                     ['吳宛財']
# 32                              ['林于岳', '黃于安']
# 33                                     ['曾裕仁']
#
#                                 QAoutput_split  \
# 0                 ['何水巡', '李林豐', '林佐漢', '王玉明']
# 1                               ['王勇志', '陳致遠']
# 2                               ['方韋成', '陳俊希']
# 3                 ['張涵寧', '許皓彥', '鄭柏廷', '陳致遠']
# 4                                      ['許育心']
# 5                               ['余哲榮', '黃千菁']
# 6                        ['池豪蓮', '鄭信宏', '黃明倫']
# 7                 ['何淑卿', '劉冠恬', '彭俊緯', '白琳治']
# 8                               ['胡竣泉', '郭詠奇']
# 9                                      ['范志宏']
# 10                                     ['林韋志']
# 11                              ['吳宛財', '羅友菱']
# 12                                     ['林威成']
# 13                                     ['許宛玲']
# 14                       ['張智元', '林子芸', '陳怡岑']
# 15                                     ['張舒宸']
# 16                ['吳舒羽', '李誠芬', '陳珮發', '黃小軒']
# 17                              ['曾裕仁', '趙豪伸']
# 18                              ['林燕樺', '陳瑋倫']
# 19                                     ['張昱廷']
# 20                              ['許宏儒', '黃靜天']
# 21                                     ['吳雨木']
# 22                                     ['吳慧敏']
# 23  ['唐雅雯', '李碧青', '林宗威', '林秀琦', '鄭旭丹', '陳雅映']
# 24                                     ['黃信怡']
# 25              ['林盈中', '林與林佳慧', '蔡雅歡', '陳玠源']
# 26                       ['劉惠雯', '劉成秀', '劉舜宜']
# 27                              ['王子南', '羅則嬌']
# 28                                     ['馮智堯']
# 29                                     ['謝郁涵']
# 30                ['陳俊希', '陳弘俊', '陳瑋婷', '黃靜天']
# 31                                     ['吳宛財']
# 32                              ['林于岳', '黃于安']
# 33                                     ['曾裕仁']
#
#                                  ckip+QAoutput  \
# 0                 ['何水巡', '李林豐', '林佐漢', '王玉明']
# 1                               ['王勇志', '陳致遠']
# 2                                      ['方韋成']
# 3                 ['張涵寧', '許皓彥', '鄭柏廷', '陳致遠']
# 4                               ['林怡伶', '許育心']
# 5                        ['余哲榮', '祁姵瑜', '黃千菁']
# 6                 ['吳雅沛', '池豪蓮', '鄭信宏', '黃明倫']
# 7          ['何淑卿', '劉冠恬', '彭俊緯', '涂婉如', '白琳治']
# 8                               ['胡竣泉', '郭詠奇']
# 9                                      ['范志宏']
# 10                                     ['林韋志']
# 11                              ['吳宛財', '羅友菱']
# 12                                     ['林威成']
# 13                              ['林雅屏', '許宛玲']
# 14                ['張智元', '林子芸', '游怡如', '陳怡岑']
# 15                                     ['張舒宸']
# 16                              ['吳舒羽', '李誠芬']
# 17                       ['徐彩媚', '曾裕仁', '趙豪伸']
# 18                       ['徐雲其', '林燕樺', '陳瑋倫']
# 19                                     ['張昱廷']
# 20                       ['曾靖雅', '王吟芳', '黃靜天']
# 21                                     ['吳雨木']
# 22                                     ['吳慧敏']
# 23  ['唐雅雯', '李海喜', '李碧青', '林宗威', '林秀琦', '鄭旭丹']
# 24                              ['黃信怡', '黃入監']
# 25                              ['蔡雅歡', '陳玠源']
# 26                       ['劉惠雯', '劉成秀', '劉舜宜']
# 27                              ['王子南', '鐘辛禾']
# 28                                     ['馮智堯']
# 29                                     ['謝郁涵']
# 30                                     ['黃靜天']
# 31                                     ['吳宛財']
# 32                              ['林于岳', '黃于安']
# 33                                     ['曾裕仁']
#
#                                   ckip+QAoutput_split
# 0                        ['何水巡', '李林豐', '林佐漢', '王玉明']
# 1                                      ['王勇志', '陳致遠']
# 2                                      ['方韋成', '陳俊希']
# 3                        ['張涵寧', '許皓彥', '鄭柏廷', '陳致遠']
# 4                               ['林怡伶', '林秀瑋', '許育心']
# 5                               ['余哲榮', '祁姵瑜', '黃千菁']
# 6                               ['池豪蓮', '鄭信宏', '黃明倫']
# 7                 ['何淑卿', '劉冠恬', '彭俊緯', '涂婉如', '白琳治']
# 8                                      ['胡竣泉', '郭詠奇']
# 9                                             ['范志宏']
# 10                                            ['林韋志']
# 11                                     ['吳宛財', '羅友菱']
# 12                                            ['林威成']
# 13                                            ['許宛玲']
# 14                       ['張智元', '林子芸', '游怡如', '陳怡岑']
# 15                                            ['張舒宸']
# 16                       ['吳舒羽', '李誠芬', '陳珮發', '黃小軒']
# 17                                     ['曾裕仁', '趙豪伸']
# 18                                     ['林燕樺', '陳瑋倫']
# 19                                            ['張昱廷']
# 20                                     ['許宏儒', '黃靜天']
# 21                                            ['吳雨木']
# 22                                            ['吳慧敏']
# 23  ['唐雅雯', '李碧青', '林宗威', '林秀琦', '林雅云', '鄭旭丹', '陳雅映']
# 24                                            ['黃信怡']
# 25              ['林佳慧', '林盈中', '林與林佳慧', '蔡雅歡', '陳玠源']
# 26                              ['劉惠雯', '劉成秀', '劉舜宜']
# 27                              ['王子南', '羅則嬌', '鐘辛禾']
# 28                                            ['馮智堯']
# 29                                            ['謝郁涵']
# 30                       ['陳俊希', '陳弘俊', '陳瑋婷', '黃靜天']
# 31                                            ['吳宛財']
# 32                                     ['林于岳', '黃于安']
# 33                                            ['曾裕仁']

# %%
QA_list = []
QA_split_list = []
ckip_QA_list = []
ckip_QA_split_list = []
for index,row in pred.iterrows():
        qa_ans = ast.literal_eval(row['QAoutput'])
        QA_list.append(qa_ans)
        qa_split_ans = ast.literal_eval(row['QAoutput_split'])
        QA_split_list.append(qa_split_ans)
        ckip_qa_ans = ast.literal_eval(row['ckip+QAoutput'])
        ckip_QA_list.append(ckip_qa_ans)
        ckip_qa_split_ans = ast.literal_eval(row['ckip+QAoutput_split'])
        ckip_QA_split_list.append(ckip_qa_split_ans)
# Out:
# [['何水巡', '李林豐', '林佐漢', '王玉明'],
#  ['王勇志', '陳致遠'],
#  ['方韋成', '陳俊希'],
#  ['張涵寧', '許皓彥', '鄭柏廷', '陳致遠'],
#  ['許育心'],
#  ['余哲榮', '黃千菁'],
#  ['池豪蓮', '鄭信宏', '黃明倫'],
#  ['何淑卿', '劉冠恬', '彭俊緯', '白琳治'],
#  ['胡竣泉', '郭詠奇'],
#  ['范志宏'],
#  ['林韋志'],
#  ['吳宛財', '羅友菱'],
#  ['林威成'],
#  ['許宛玲'],
#  ['張智元', '林子芸', '陳怡岑'],
#  ['張舒宸'],
#  ['吳舒羽', '李誠芬', '陳珮發', '黃小軒'],
#  ['曾裕仁', '趙豪伸'],
#  ['林燕樺', '陳瑋倫'],
#  ['張昱廷'],
#  ['許宏儒', '黃靜天'],
#  ['吳雨木'],
#  ['吳慧敏'],
#  ['唐雅雯', '李碧青', '林宗威', '林秀琦', '鄭旭丹', '陳雅映'],
#  ['黃信怡'],
#  ['林盈中', '林與林佳慧', '蔡雅歡', '陳玠源'],
#  ['劉惠雯', '劉成秀', '劉舜宜'],
#  ['王子南', '羅則嬌'],
#  ['馮智堯'],
#  ['謝郁涵'],
#  ['陳俊希', '陳弘俊', '陳瑋婷', '黃靜天'],
#  ['吳宛財'],
#  ['林于岳', '黃于安'],
#  ['曾裕仁']]

# %%
def eval(pred, ans):
    if bool(pred) is not bool(ans):
        return 0
    elif not pred and not ans:
        return 1
    else:
        pred = set(pred)
        ans = set(ans)
        interaction_len = len(pred & ans)
        if interaction_len == 0:
            return 0

        pred_len = len(pred)
        ans_len = len(ans)
        return 2 / (pred_len / interaction_len + ans_len / interaction_len)


def eval_all(pred_list, ans_list):
    assert len(pred_list) == len(ans_list)
    return sum(eval(p, a) for p, a in zip(pred_list, ans_list)) / len(pred_list)

# %%
#傳讀進來的csv 可能要注意自己欄位的命名
def get_score_july_thirty(pred):
    #人工抓的正解
    data = pd.read_csv('./tbrain/2020-07-30_ans.csv')
    ans_list = []
    correct =data[data['binary']==1]
    for index,row in correct.iterrows():
        name_ans = ast.literal_eval(row['ans'])
        ans_list.append(name_ans)
    QA_list = []
    QA_split_list = []
    ckip_QA_list = []
    ckip_QA_split_list = []
    #宏昀的答案們
    for index,row in pred.iterrows():
        qa_ans = ast.literal_eval(row['QAoutput'])
        QA_list.append(qa_ans)
        qa_split_ans = ast.literal_eval(row['QAoutput_split'])
        QA_split_list.append(qa_split_ans)
        ckip_qa_ans = ast.literal_eval(row['ckip+QAoutput'])
        ckip_QA_list.append(ckip_qa_ans)
        ckip_qa_split_ans = ast.literal_eval(row['ckip+QAoutput_split'])
        ckip_QA_split_list.append(ckip_qa_split_ans)
    print("QA score:",eval_all(QA_list,ans_list))
    print("QA_split score:",eval_all(QA_split_list,ans_list))
    print("ckip+QA score:",eval_all(ckip_QA_list,ans_list))
    print("ckip+QA_split score:",eval_all(ckip_QA_split_list,ans_list))

# %%
pred = pd.read_csv('./tbrain/2020-07-30_QA_validation.csv')
get_score_july_thirty(pred)
# Out:
# QA score: 0.8415032679738561
# QA_split score: 0.901844070961718
# ckip+QA score: 0.8333800186741362
# ckip+QA_split score: 0.9379084967320263

# %%
n =['陳珮如', '楊建豪', '林銘江', '黃嘉為', '黃尹善', '王淑慧', '侯忠翰', '盧巧火', '謝孟惠', '柯鈺容', '蔡翔富', '陳祥希', '張冠宏', '張嘉劭', '鄧揚原', '蔡俊吉', '李佳源', '陳文豪', '楊宜芳', '劉詩婷', '陳品禾', '李佳仲', '許佳蓉', '李宣雅', '張家欣', '陳詠柏', '魏剛彥', '蔡佳芷', '林嘉吟', '曹玉婷', '蔡詩婷', '冉怡芬', '黃欣穎', '韓惠文', '胡威廷', '黃香馨', '賴佳玲', '宋俊宏', '黃建陽', '曾淑媛', '林智偉', '屠益枝', '陳朝妹', '彭世傑', '詹夢璇', '張祐生', '倪若康','杜靜宜', '黃俊順', '施坤鴻', '王智鈺', '柳書瑋', '陳士豪', '慕興羽', '張星宇', '謝孟汝', '陳怡君', '許姿妤', '楊家瑜', '陳依仲', '陳婉菁', '李嘉玲', '李玄弘', '蘇振豪', '游恭蓁', '劉美玲', '李政宏', '張中揚', '李育辛', '林彥瑜', '甘家弘', '翁詩婷', '林怡萱', '林怡男', '劉伶寧', '陳韻剛', '潘堅方', '韓寶為', '陳英傑', '瞿正映', '方宜臻', '李志偉', '陳逸竹', '鄧韋伶', '王宛儒', '林怡芳', '謝雅雯', '李美惠', '王心怡', '黃正威', '張雅玲', '廖偉易', '蘇正偉', '陳治啟', '陳志穎', '陳姵君', '陳彥翔', '黎佳玲', '洪妤均', '蔡建宇', '郭芳儀', '劉淑珍', '吳中珊', '姜雅萍', '虞宥柏', '黃志生', '林美玲', '陳政瑞', '陳政孝', '戴奇妮', '黃柏珊', '賴宇紫', '林婉婷', '蔡宜辰', '陳世謙', '鄭銘源', '楊怡如', '林允俐', '金怡君', '謝慧茹', '蔡忠雨', '林家誠', '許嘉淳', '葉慧君', '劉郁翔', '張慧敏', '林雅婷', '林建慈', '黃致原', '李菁青', '張昇麟', '郭淑芬', '馬珮雯', '呂雅萍', '鄭淑婷', '方靜豪', '李白能', '陳怡貴', '張宗儒', '葉映菁', '林淑君', '邱致茹', '陳盈芳', '吳宛菱', '郭曼治', '劉康禎', '李靜瑋', '楊子佳', '吳建智', '劉珮君', '陳秀松', '李婉吉', '吳雅筠', '林怡禎', '林卓芷', '陳俐達', '吳天威', '葉介茂', '鄧政霖', '林佳霖', '倪鈺雯', '劉彥亨', '白郁翔', '張昱廷', '劉淑州', '藍欣怡', '林雅源', '王明哲', '王惠如', '李建珠', '張貴正', '李威廷', '連偉婷', '楊秀旺', '林思妤', '幸貴香', '林東隆', '陳山喬', '楊思婷', '齊宗東', '鄭雅惠', '王嘉士', '陳國齊', '黃舜文', '張淑松', '常麗君', '王翔伯', '連禎光', '袁�
'吳宛玲', '陳慧廷', '黃凱妹', '曾鈺婷', '周思婷', '吳文彬', '王于婷', '賴孟修', '王勳仰', '王馨儀', '王妍偉', '劉柏成', '林正定', '夏建志', '傅志祥', '劉宗翰', '謝光奇', '許耀霞', '徐偉哲', '陳惠昌', '藍怡伶', '李永梅', '黃姿文', '楊志文', '陳惠芬', '許佩儒', '許國瑋', '張佑堅', '沈怡潔', '陳怡伶', '蘇淑敏', '丁瑞尹', '黃瓊富', '王嘉琪', '杜欣潔', '吳康珠', '林芳雄', '劉佳茂', '李依岳', '黃惠琪', '陳佳雯', '張偉智', '潘玉婷', '王信豪', '王安琪', '謝毓泉', '宋威琦', '涂致裕', '朱裕翔', '陳瑜依', '王雪瑩', '周家豪', '謝惟花', '黃英傑', '潘少火', '孫馨儀', '夏逸凡', '劉惠雯', '彭玫豪', '王佳火', '陳旭芝', '石雅婷', '陳美文', '郭文祥', '林岱夫', '曾恒容', '李宜虹', '施婉婷', '蔡倫蕙', '劉向陽', '陳政宏', '許喜瑜', '謝憲卉', '許哲香', '林欣禮', '張平貞', '廖家皓']
n = np.array(n)

# %%
train = pd.read_csv('./tbrain/tbrain_train_split.csv')
train = train.dropna()
print(train)
# Out:
#       news_ID name                                       full_content  \
# 6        1984  鄭銘富  鄭銘富走私運毒集團將K他命藏在人造石板，從大陸廈門港裝貨櫃運抵基隆港，去年5月29日遭檢調查...
# 7        1984  呂家緯  鄭銘富走私運毒集團將K他命藏在人造石板，從大陸廈門港裝貨櫃運抵基隆港，去年5月29日遭檢調查...
# 8        1984  李春生  鄭銘富走私運毒集團將K他命藏在人造石板，從大陸廈門港裝貨櫃運抵基隆港，去年5月29日遭檢調查...
# 9        1984  黃建強  鄭銘富走私運毒集團將K他命藏在人造石板，從大陸廈門港裝貨櫃運抵基隆港，去年5月29日遭檢調查...
# 10       1984  周正華  鄭銘富走私運毒集團將K他命藏在人造石板，從大陸廈門港裝貨櫃運抵基隆港，去年5月29日遭檢調查...
# ...       ...  ...                                                ...
# 4897      398  陳國帥  前黑澀會美眉「薔薔」林嘉凌，再爆出吸毒疑雲！檢警接獲線報，指稱北市大直一處豪宅有人辦毒趴，台...
# 4922     1418  吳誌麒  ▲「吳董」賣淫集團遭破獲，首腦遭判刑3年。（圖／資料照）\n\n記者許力方／綜合報導\n移民...
# 4923     1418  邱文聰  ▲「吳董」賣淫集團遭破獲，首腦遭判刑3年。（圖／資料照）\n\n記者許力方／綜合報導\n移民...
# 4924     1418  溫方瓊  ▲「吳董」賣淫集團遭破獲，首腦遭判刑3年。（圖／資料照）\n\n記者許力方／綜合報導\n移民...
# 4938     4728  顏政德  詐領助理費 國民黨竹市議員顏政德判刑4年4月\n國民黨竹市議員顏政德（右）詐領助理費，新竹地...
#
#                                              ckip_names
# 6     ['於鄭', '高振殷', '鄭', '鄭銘富', '周正華', '呂家緯', '高男', ...
# 7     ['於鄭', '高振殷', '鄭', '鄭銘富', '周正華', '呂家緯', '高男', ...
# 8     ['於鄭', '高振殷', '鄭', '鄭銘富', '周正華', '呂家緯', '高男', ...
# 9     ['於鄭', '高振殷', '鄭', '鄭銘富', '周正華', '呂家緯', '高男', ...
# 10    ['於鄭', '高振殷', '鄭', '鄭銘富', '周正華', '呂家緯', '高男', ...
# ...                                                 ...
# 4897  ['林茂樹', '諧星薔', '陳國帥', '紀', '陳', '薔薔', '林嘉凌', '...
# 4922  ['吳誌麒', '溫方瓊', '茜', '雙北', '文哥', '吳董', '丁國琳', '...
# 4923  ['吳誌麒', '溫方瓊', '茜', '雙北', '文哥', '吳董', '丁國琳', '...
# 4924  ['吳誌麒', '溫方瓊', '茜', '雙北', '文哥', '吳董', '丁國琳', '...
# 4938                               ['顏之', '蔡彰盛', '顏政德']
#
# [873 rows x 4 columns]

# %%
#正確的答案
all_name = []
ckip_name = train['ckip_names']
true_label = []
#混和後的結果
result = []
correct = train['name']
#百家姓 共177個
hundred_name = ['趙','錢','孫','李','周','吳','鄭','王','馮','陳','褚','衛','蔣','沈','韓','楊','朱','秦','尤','許','何','呂','施','張','孔','曹','嚴','華','金','魏','陶','姜','戚','謝','鄒','章','蘇','潘','葛','范','彭','魯','韋','馬','苗','花','方','俞','任','袁','柳','鮑','史','唐','費','廉','薛','雷','賀','倪','湯','殷','羅','郝','安','于','傅','齊','康','伍','余','顧','孟','黃','蕭','尹','姚','邵','汪','毛','狄','戴','宋','龐','熊','紀','屈','項','祝','董','梁','杜','阮','藍','季','賈','江','童','顏','郭','盛','林','鍾','徐','邱','駱','高','夏','蔡','田','樊','胡','凌','霍','萬','柯','管','盧','莫','繆','解','應','丁','鄧','洪','包','石','崔','龔','程','裴','陸','甄','封','糜','焦','侯','全','甘','武','劉','詹','龍','葉','黎','白','邰','賴','卓','池','譚','溫','莊','瞿','連','習','向','古','易','廖','耿','歐','冷','簡','曾','司馬','上官','歐陽','夏侯','諸葛','東方','公孫','慕容','端木','拓跋','呼延','牟']
#可能的錯7個
wrong_list=['男','女','嫌','妻','夫','姓','應','為','董','哥','姊','姐','總',,'']
for data in correct:
    all_name.append(data)
    true_label.append(1)
all_name=np.array(all_name)
all_name = np.concatenate((all_name,n),axis=0)
for data in n:
    true_label.append(1)
true_label = np.array(true_label)
print(all_name.shape)
print(true_label.shape)
# Out:
# (1570,)
# (1570,)

# %%
wrong_name =[]
false_label = []
for i in hundred_name:
    for j in wrong_list:
        put = i+j
        wrong_name.append(put)
        false_label.append(0)
wrong_name=np.array(wrong_name)
false_label=np.array(false_label)
print(wrong_name.shape)
print(false_label.shape)
# Out:
# (2655,)
# (2655,)

# %%
#all name &label
name = np.concatenate((all_name,wrong_name),axis=0)
label = np.concatenate((true_label,false_label),axis=0)
print(name.shape)
print(label.shape)
# Out:
# (4225,)
# (4225,)

# %%
data = np.array([name,label])
data = data.swapaxes(0,1)
np.random.shuffle(data)
print(data)
# Out:
# [['邱嘉進' '1']
#  ['周家豪' '1']
#  ['施總' '0']
#  ...
#  ['唐董' '0']
#  ['黃為' '0']
#  ['許鴻呈' '1']]

# %%
df=pd.DataFrame(data)
df.to_csv('./tbrain/train_name.csv',index=0)
